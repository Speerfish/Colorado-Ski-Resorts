# %%
# Step 1: Import the necessary libraries
import pandas as pd
import folium

# %%
# Step 2: Load the CSV file into a pandas DataFrame
file_path = 'Ski Resorts.csv'  # Replace with your file's correct path
df = pd.read_csv(file_path)

# Display the first few rows to check the data
df.head(10)
# Out:
#               Name     Nearest city Skiable area (acres) Top elevation (feet)  \
# 0   Arapahoe Basin           Dillon                1,428               13,050
# 1  Aspen Highlands            Aspen                1,040               12,392
# 2   Aspen Mountain            Aspen                  675               11,212
# 3     Beaver Creek     Beaver Creek                1,832               11,440
# 4     Breckenridge     Breckenridge                2,908               12,998
# 5       Buttermilk            Aspen                  470                9,900
# 6       Ski Cooper        Leadville                  470               11,700
# 7  Copper Mountain  Copper Mountain                2,490               12,441
# 8    Crested Butte    Crested Butte                1,547               12,162
# 9    Echo Mountain        Evergreen                   60               10,650
#
#   Base elevation (feet) Vertical (feet)  Runs  Lifts  Snowfall (in/year)  \
# 0                10,520           2,530   147      9                 314
# 1                 8,040           4,352   117      5                 300
# 2                 7,945           3,267    76      8                 300
# 3                 8,100           3,340   150     23                 325
# 4                 9,600           3,398   187     34                 282
# 5                 7,870           2,030    44      8                 200
# 6                10,500           1,200    60      5                 260
# 7                 9,712           2,738   140     24                 278
# 8                 9,375           2,787   121     15                 253
# 9                10,050             600    13      3                 275
#
#     Latitude   Longitude                                            Website  \
# 0  39.642126 -105.872464                          http://arapahoebasin.com/
# 1  39.181111 -106.856389  https://www.aspensnowmass.com/four-mountains/a...
# 2  39.186485 -106.818264  https://www.aspensnowmass.com/four-mountains/a...
# 3  39.602398 -106.516914  https://www.beavercreek.com/the-mountain/about...
# 4  39.473880 -106.073910  https://www.breckenridge.com/the-mountain/abou...
# 5  39.183611 -106.896667  https://www.aspensnowmass.com/four-mountains/b...
# 6  39.360544 -106.302247                         https://www.skicooper.com/
# 7  39.499917 -106.155921                    https://www.coppercolorado.com/
# 8  38.869800 -106.984000  https://www.skicb.com/the-mountain/about-the-m...
# 9  39.685000 -105.519000                               https://echomtn.com/
#
#    Phone Number         Tel                              Email
# 0  888-272-7246  8882727246          guestservices@a-basin.net
# 1  800-525-6200  8005256200        contactus@aspensnowmass.com
# 2  800-525-6200  8005256200        contactus@aspensnowmass.com
# 3  970-754-0005  9707540005  info@beavercreekresortcompany.com
# 4  970-453-5000  9704535000          breckinfo@vailresorts.com
# 5  800-525-6200  8005256200        contactus@aspensnowmass.com
# 6  719-486-2277  7194862277                 info@skicooper.com
# 7  866-656-1546  8666561546            info@coppercolorado.com
# 8  877-547-5143  8775475143                     info@skicb.com
# 9  970-531-5038  9705315038                   info@echomtn.com

# %%
# Step 3: Filter the DataFrame to select relevant columns
columns = [
    'Name', 'Nearest city', 'Skiable area (acres)', 'Top elevation (feet)',
    'Vertical (feet)', 'Runs', 'Lifts', 'Snowfall (in/year)',
    'Latitude', 'Longitude', 'Website', 'Phone Number', 'Tel', 'Email'
]
df_filtered = df[columns]

# Drop rows with missing latitude or longitude data
df_filtered = df_filtered.dropna(subset=['Latitude', 'Longitude'])

# Convert Latitude and Longitude to numeric values in case they are strings
df_filtered['Latitude'] = pd.to_numeric(df_filtered['Latitude'], errors='coerce')
df_filtered['Longitude'] = pd.to_numeric(df_filtered['Longitude'], errors='coerce')

# Display the filtered DataFrame
df_filtered.head(10)
# Out:
#               Name     Nearest city Skiable area (acres) Top elevation (feet)  \
# 0   Arapahoe Basin           Dillon                1,428               13,050
# 1  Aspen Highlands            Aspen                1,040               12,392
# 2   Aspen Mountain            Aspen                  675               11,212
# 3     Beaver Creek     Beaver Creek                1,832               11,440
# 4     Breckenridge     Breckenridge                2,908               12,998
# 5       Buttermilk            Aspen                  470                9,900
# 6       Ski Cooper        Leadville                  470               11,700
# 7  Copper Mountain  Copper Mountain                2,490               12,441
# 8    Crested Butte    Crested Butte                1,547               12,162
# 9    Echo Mountain        Evergreen                   60               10,650
#
#   Vertical (feet)  Runs  Lifts  Snowfall (in/year)   Latitude   Longitude  \
# 0           2,530   147      9                 314  39.642126 -105.872464
# 1           4,352   117      5                 300  39.181111 -106.856389
# 2           3,267    76      8                 300  39.186485 -106.818264
# 3           3,340   150     23                 325  39.602398 -106.516914
# 4           3,398   187     34                 282  39.473880 -106.073910
# 5           2,030    44      8                 200  39.183611 -106.896667
# 6           1,200    60      5                 260  39.360544 -106.302247
# 7           2,738   140     24                 278  39.499917 -106.155921
# 8           2,787   121     15                 253  38.869800 -106.984000
# 9             600    13      3                 275  39.685000 -105.519000
#
#                                              Website  Phone Number  \
# 0                          http://arapahoebasin.com/  888-272-7246
# 1  https://www.aspensnowmass.com/four-mountains/a...  800-525-6200
# 2  https://www.aspensnowmass.com/four-mountains/a...  800-525-6200
# 3  https://www.beavercreek.com/the-mountain/about...  970-754-0005
# 4  https://www.breckenridge.com/the-mountain/abou...  970-453-5000
# 5  https://www.aspensnowmass.com/four-mountains/b...  800-525-6200
# 6                         https://www.skicooper.com/  719-486-2277
# 7                    https://www.coppercolorado.com/  866-656-1546
# 8  https://www.skicb.com/the-mountain/about-the-m...  877-547-5143
# 9                               https://echomtn.com/  970-531-5038
#
#           Tel                              Email
# 0  8882727246          guestservices@a-basin.net
# 1  8005256200        contactus@aspensnowmass.com
# 2  8005256200        contactus@aspensnowmass.com
# 3  9707540005  info@beavercreekresortcompany.com
# 4  9704535000          breckinfo@vailresorts.com
# 5  8005256200        contactus@aspensnowmass.com
# 6  7194862277                 info@skicooper.com
# 7  8666561546            info@coppercolorado.com
# 8  8775475143                     info@skicb.com
# 9  9705315038                   info@echomtn.com

# %%
# Step 4: Create a Folium map centered on Colorado
colorado_map = folium.Map(location=[39.5501, -105.7821], zoom_start=7)  # Approximate center of Colorado

# Step 5: Add markers for each ski resort
for idx, row in df_filtered.iterrows():
    # Extract resort information
    name = row['Name']
    nearest_city = row['Nearest city']
    skiable_area = row['Skiable area (acres)']
    top_elevation = row['Top elevation (feet)']
    vertical = row['Vertical (feet)']
    runs = row['Runs']
    lifts = row['Lifts']
    snowfall = row['Snowfall (in/year)']
    website = row['Website']
    phone = row['Phone Number']
    tel = row['Tel']
    email = row['Email']
    latitude = row['Latitude']
    longitude = row['Longitude']
    
    # Create the popup content with ski resort details
    popup_content = (
        f"""
        <b>Name:</b> {name}<br>
        <b>Nearest City:</b> {nearest_city}<br>
        <b>Skiable Area (acres):</b> {skiable_area}<br>
        <b>Top Elevation (feet):</b> {top_elevation}<br>
        <b>Vertical (feet):</b> {vertical}<br>
        <b>Runs:</b> {runs}<br>
        <b>Lifts:</b> {lifts}<br>
        <b>Snowfall (in/year):</b> {snowfall}<br>
        <b>Website:</b> <a href="{website}">{website}</a><br>
        <b>Phone:</b> <a href="tel:{tel}">{phone}</a><br>
        <b>Email:</b> <a href="mailto:{email}">{email}</a><br>
        """
    )
    
    # Add a marker for the ski resort
    folium.Marker(
        location=[latitude, longitude],
        popup=folium.Popup(popup_content, max_width=300),
        icon=folium.Icon(color='green', icon='skiing', prefix='fa')
    ).add_to(colorado_map)

# Step 6: Display the map
colorado_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c8ed46329ebf269c673ea9746791f5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c8ed46329ebf269c673ea9746791f5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c8ed46329ebf269c673ea9746791f5b = L.map(
#                 &quot;map_7c8ed46329ebf269c673ea9746791f5b&quot;,
#                 {
#                     center: [39.5501, -105.7821],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ecf8ad21827275b9bd189c66e3d7515 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0ecf8ad21827275b9bd189c66e3d7515.addTo(map_7c8ed46329ebf269c673ea9746791f5b);
#
#
#             var marker_a4fd6a0cbd70cda0d4d786a828295fd3 = L.marker(
#                 [39.6421261, -105.872464],
#                 {}
#             ).addTo(map_7c8ed46329ebf269c673ea9746791f5b);
#
#
#             var icon_d54cd8a9b5a69110b314e48896b50b15 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;skiing&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a4fd6a0cbd70cda0d4d786a828295fd3.setIcon(icon_d54cd8a9b5a69110b314e48896b50b15);
#
#
#         var popup_34c90d440222f41bceff072233cc0049 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_39c1018413a204f8dcccfa96277a5c13 = $(`&lt;div id=&quot;html_39c1018413a204f8dcccfa96277a5c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Name:&lt;/b&gt; Arapahoe Basin&lt;br&gt;         &lt;b&gt;Nearest City:&lt;/b&gt; Dillon&lt;br&gt;         &lt;b&gt;Skiable Area (acres):&lt;/b&gt; 1,428&lt;br&gt;         &lt;b&gt;Top Elevation (feet):&lt;/b&gt; 13,050&lt;br&gt;         &lt;b&gt;Vertical (feet):&lt;/b&gt; 2,530&lt;br&gt;         &lt;b&gt;Runs:&lt;/b&gt; 147&lt;br&gt;         &lt;b&gt;Lifts:&lt;/b&gt; 9&lt;br&gt;         &lt;b&gt;Snowfall (in/year):&lt;/b&gt; 314&lt;br&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=&quot;http://arapahoebasin.com/&quot;&gt;http://arapahoebasin.com/&lt;/a&gt;&lt;br&gt;         &lt;b&gt;Phone:&lt;/b&gt; &lt;a href=&quot;tel:8882727246&quot;&gt;888-272-7246&lt;/a&gt;&lt;br&gt;         &lt;b&gt;Email:&lt;/b&gt; &lt;a href=&quot;mailto:guestservices@a-basin.net&quot;&gt;guestservices@a-basin.net&lt;/a&gt;&lt;br&gt;         &lt;/div&gt;`)[0];
#                 popup_34c90d440222f41bceff072233cc0049.setContent(html_39c1018413a204f8dcccfa96277a5c13);
#
#
#
#         marker_a4fd6a0cbd70cda0d4d786a828295fd3.bindPopup(popup_34c90d440222f41bceff072233cc0049)
#         ;
#
#
#
#
#             var marker_4fc75a3fc6d9ec15db542faf382c0a1d = L.marker(
#                 [39.181111, -106.856389],
#                 {}
#             ).addTo(map_7c8ed46329ebf269c673ea9746791f5b);
#
#
#             var icon_be2804642cd47c1192c6d1ceb5ffd05f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;skiing&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4fc75a3fc6d9ec15db542faf382c0a1d.setIcon(icon_be2804642cd47c1192c6d1ceb5ffd05f);
#
#
#         var popup_af39becf84efa118e47e683791db90e3 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_f8de7123c1a09f44849632240a4ea7c4 = $(`&lt;div id=&quot;html_f8de7123c1a09f44849632240a4ea7c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;         &lt;b&gt;Name:&lt;/b&gt; Aspen Highlands&lt;br&gt;         &lt;b&gt;Nearest City:&lt;/b&gt; Aspen&lt;br&gt;         &lt;b&gt;Skiable Area (acres):&lt;/b&gt; 1,040&lt;br&gt;         &lt;b&gt;Top Elevation (feet):&lt;/b&gt; 12,392&lt;br&gt;         &lt;b&gt;Vertical (feet):&lt;/b&gt; 4,352&lt;br&gt;         &lt;b&gt;Runs:&lt;/b&gt; 117&lt;br&gt;         &lt;b&gt;Lifts:&lt;/b&gt; 5&lt;br&gt;         &lt;b&gt;Snowfall (in/year):&lt;/b&gt; 300&lt;br&gt;         &lt;b&gt;Website:&lt;/b&gt; &lt;a href=&quot;https://www.aspensnowmass.com/four-mountains/aspen-highlands&quot;&gt;https://www.aspensnowmass.com/four-mountains/aspen-highlands&lt;/a&gt;&lt;br&gt;         &lt;b&gt;Phone:&lt;/b&gt; &lt;a href=&quot;tel:8005256200&quot;&gt;800-525-6200&lt;/a&gt;&lt;br&gt;         &lt;b&gt;Email:&lt;/b&gt; &lt;a href=&quot;mailto:contactus@aspensnowmass.com&quot;&gt;contactus@aspensnowmass.com&lt;/a&gt;&lt;br&gt;         &lt;/div&gt;`)[0];
#                 popup_af39becf84efa118e47e683791db90e3.setContent(html_f8de7123c1a09f44849632240a4ea7c4);
#
#
#
#         marker_4fc75a3fc6d9ec15db542faf382c0a1d.bindPopup(popup_af39becf84efa118e47e683791d

# %%
# Step 7: Save the map to an HTML file
colorado_map.save("colorado_ski_resorts_map.html")
